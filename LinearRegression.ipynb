# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv("cost_revenue_clean.csv")

# %%
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
x = DataFrame(data, columns=["production_budget_usd"])
y = DataFrame(data, columns=["worldwide_gross_usd"])

# %%
plt.figure(figsize = (10, 6))
plt.scatter(x,y, alpha=0.3)
plt.title("Film production cost and global revenue")
plt.xlabel("Production buudget in $")
plt.ylabel("Global revenue in $")
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.show()

# %%
regression = LinearRegression()
regression.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope Coefficient

# %%
regression.coef_  #theta_1
# Out:
# array([[3.11150918]])

# %% [markdown]
# Intercept:

# %%
regression.intercept_
# Out:
# array([-7236192.72913969])

# %%
plt.figure(figsize = (20, 12))
plt.scatter(x,y, alpha=0.3)
plt.plot(x, regression.predict(x), color="red", linewidth=4)
#plt.plot(x,y) we are using regression.predict(x) , we are using the predicted x value instead of the real y value.


plt.title("Film production cost and global revenue")
plt.xlabel("Production buudget in $")
plt.ylabel("Global revenue in $")
plt.xlim(0, 450000000)
plt.ylim(0, 3000000000)
plt.show()
